# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r"C:\Users\JEEVAN\HospitalPatientDataAnalysis\data\raw\patient.csv")

# %%
df_original=pd.DataFrame(data)

# %%
df_original.head()
# Out:
#   patient_id admission_date  season  age  gender region primary_diagnosis  \
# 0     P00001     14-04-2022  Spring   66    Male  South          Diabetes
# 1     P00002     19-09-2021    Fall   55    Male  South          Diabetes
# 2     P00003     12-04-2023  Spring   69  Female   West      Hypertension
# 3     P00004     14-08-2023  Summer   83    Male  South            Stroke
# 4     P00005     05-11-2021    Fall   54  Female  North            Stroke
#
#    comorbidities_count  length_of_stay  treatment_type  medications_count  \
# 0                    5               6  Interventional                  8
# 1                    4               6  Interventional                  6
# 2                    6               8         Medical                  9
# 3                    6              11         Medical                 11
# 4                    4              10         Medical                  6
#
#    followup_visits_last_year  prev_readmissions insurance_type  \
# ...

# %%
df=df_original.copy()

# %%
df["gender"]=df["gender"].map({"Male":1,"Female":0})

# %%
df
# Out:
#      patient_id admission_date  season  age  gender region primary_diagnosis  \
# 0        P00001     14-04-2022  Spring   66       1  South          Diabetes
# 1        P00002     19-09-2021    Fall   55       1  South          Diabetes
# 2        P00003     12-04-2023  Spring   69       0   West      Hypertension
# 3        P00004     14-08-2023  Summer   83       1  South            Stroke
# 4        P00005     05-11-2021    Fall   54       0  North            Stroke
# ...         ...            ...     ...  ...     ...    ...               ...
# 7995     P07996     11-01-2022  Winter   95       0   East              COPD
# 7996     P07997     05-05-2022  Spring   63       0   East    Kidney Disease
# 7997     P07998     26-08-2021  Summer   43       0   East          Diabetes
# 7998     P07999     20-04-2021  Spring   86       1   West            Sepsis
# 7999     P08000     12-06-2021  Summer   93       0  North    Kidney Disease
#
# ...

# %%
df.to_csv(r"C:\Users\JEEVAN\HospitalPatientDataAnalysis\data\processed\patient_cleaned.csv", index=False)

# %%
#EDA FOR CLASS IMBALANCE
label=["readmission","not read mission"]
df["label"].value_counts().plot(kind="pie",autopct="%1.1f%%")


plt.savefig(r"C:\Users\JEEVAN\HospitalPatientDataAnalysis\output\plots\readmission_distribution.png")
plt.show()
